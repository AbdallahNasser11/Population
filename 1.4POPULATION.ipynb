# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
pop = pd.read_csv(r"C:\Users\htc\Desktop\Power Bi\population\new pop.csv",encoding='unicode_escape')

pop
# Out:
#     Country (or dependency)  Population 2020  Yearly Change  Net Change  \
# 0                     China       1439323776         0.0039     5540090
# 1                     India       1380004385         0.0099    13586631
# 2             United States        331002651         0.0059     1937734
# 3                 Indonesia        273523615         0.0107     2898047
# 4                  Pakistan        220892340         0.0200     4327022
# ..                      ...              ...            ...         ...
# 230              Montserrat             4992         0.0006           3
# 231        Falkland Islands             3480         0.0305         103
# 232                    Niue             1626         0.0068          11
# 233                 Tokelau             1357         0.0127          17
# 234                Holy See              801         0.0025           2
#
#      Density  (P/Km²)  Land Area (Km²)  Migrants (net) Fert. Rate Med. Age  \
# ...

# %%
pop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 235 entries, 0 to 234
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Country (or dependency)  235 non-null    object
#  1   Population 2020          235 non-null    int64
#  2   Yearly Change            235 non-null    float64
#  3   Net Change               235 non-null    int64
#  4   Density  (P/Km²)         235 non-null    int64
#  5   Land Area (Km²)          235 non-null    int64
#  6   Migrants (net)           201 non-null    float64
#  7   Fert. Rate               235 non-null    object
#  8   Med. Age                 235 non-null    object
#  9   Urban Pop %              235 non-null    object
#  10  World Share              235 non-null    float64
#  11  Capital                  215 non-null    object
#  12  Continent                215 non-null    object
#  13  Continent_pop            235 non-null    int64
# ...

# %%
empty=pop.isnull().sum()

# %%
empty=pop.isnull().sum()
cond=pop.isnull().sum()>0
empty[cond]
# Out:
# Migrants (net)    34
# Capital           20
# Continent         20
# dtype: int64

# %%
#pop["Migrants (net)"]=pop["Migrants (net)"].fillna("not define")

# %%
pop["Capital"]=pop["Capital"].fillna("not defined")

# %%
pop["Continent"]=pop["Continent"].fillna("not defined")

# %%
null=pop.isnull().sum()
cond=(pop.isnull().sum()>0)
null[cond]
# Out:
# Migrants (net)    34
# dtype: int64

# %%
pop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 235 entries, 0 to 234
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Country (or dependency)  235 non-null    object
#  1   Population 2020          235 non-null    int64
#  2   Yearly Change            235 non-null    float64
#  3   Net Change               235 non-null    int64
#  4   Density  (P/Km²)         235 non-null    int64
#  5   Land Area (Km²)          235 non-null    int64
#  6   Migrants (net)           201 non-null    float64
#  7   Fert. Rate               235 non-null    object
#  8   Med. Age                 235 non-null    object
#  9   Urban Pop %              235 non-null    object
#  10  World Share              235 non-null    float64
#  11  Capital                  235 non-null    object
#  12  Continent                235 non-null    object
#  13  Continent_pop            235 non-null    int64
# ...

# %%
pop
# Out:
#     Country (or dependency)  Population 2020  Yearly Change  Net Change  \
# 0                     China       1439323776         0.0039     5540090
# 1                     India       1380004385         0.0099    13586631
# 2             United States        331002651         0.0059     1937734
# 3                 Indonesia        273523615         0.0107     2898047
# 4                  Pakistan        220892340         0.0200     4327022
# ..                      ...              ...            ...         ...
# 230              Montserrat             4992         0.0006           3
# 231        Falkland Islands             3480         0.0305         103
# 232                    Niue             1626         0.0068          11
# 233                 Tokelau             1357         0.0127          17
# 234                Holy See              801         0.0025           2
#
#      Density  (P/Km²)  Land Area (Km²)  Migrants (net) Fert. Rate Med. Age  \
# ...

# %%
pop["Med. Age"]=pop["Med. Age"].fillna(method="ffill")

# %%
pop["Med. Age"]
# Out:
# 0        38
# 1        28
# 2        38
# 3        30
# 4        23
#        ...
# 230    N.A.
# 231    N.A.
# 232    N.A.
# 233    N.A.
# 234    N.A.
# Name: Med. Age, Length: 235, dtype: object

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
#Q1=pop["Med. Age"].quantile(0.40)
#Q3=pop["Med. Age"].quantile(0.60)
#IQR=Q3-Q1
#left_limit=Q1-1.5*IQR
#right_limit=Q3+1.5*IQR
#print("left limit ", left_limit)
#print("right limit ",right_limit)

# %%
#rang=(right_limit-left_limit)
#rang

# %%
pop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 235 entries, 0 to 234
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Country (or dependency)  235 non-null    object
#  1   Population 2020          235 non-null    int64
#  2   Yearly Change            235 non-null    float64
#  3   Net Change               235 non-null    int64
#  4   Density  (P/Km²)         235 non-null    int64
#  5   Land Area (Km²)          235 non-null    int64
#  6   Migrants (net)           201 non-null    float64
#  7   Fert. Rate               235 non-null    object
#  8   Med. Age                 235 non-null    object
#  9   Urban Pop %              235 non-null    object
#  10  World Share              235 non-null    float64
#  11  Capital                  235 non-null    object
#  12  Continent                235 non-null    object
#  13  Continent_pop            235 non-null    int64
# ...

# %%
pop
# Out:
#     Country (or dependency)  Population 2020  Yearly Change  Net Change  \
# 0                     China       1439323776         0.0039     5540090
# 1                     India       1380004385         0.0099    13586631
# 2             United States        331002651         0.0059     1937734
# 3                 Indonesia        273523615         0.0107     2898047
# 4                  Pakistan        220892340         0.0200     4327022
# ..                      ...              ...            ...         ...
# 230              Montserrat             4992         0.0006           3
# 231        Falkland Islands             3480         0.0305         103
# 232                    Niue             1626         0.0068          11
# 233                 Tokelau             1357         0.0127          17
# 234                Holy See              801         0.0025           2
#
#      Density  (P/Km²)  Land Area (Km²)  Migrants (net) Fert. Rate Med. Age  \
# ...

# %%
#pop.drop(["New_Age"],axis=1,inplace=True)

# %%
##filter وعمل عامود جديد pop.loc[pop["Med. Age"]==28,"New_Age"]=27

# %%
renam={"Country (or dependency)":"Countries","Population 2020":"Population"}

# %%
pop=pop.rename(columns=renam)
pop
# Out:
#             Countries  Population  Yearly Change  Net Change  \
# 0               China  1439323776         0.0039     5540090
# 1               India  1380004385         0.0099    13586631
# 2       United States   331002651         0.0059     1937734
# 3           Indonesia   273523615         0.0107     2898047
# 4            Pakistan   220892340         0.0200     4327022
# ..                ...         ...            ...         ...
# 230        Montserrat        4992         0.0006           3
# 231  Falkland Islands        3480         0.0305         103
# 232              Niue        1626         0.0068          11
# 233           Tokelau        1357         0.0127          17
# 234          Holy See         801         0.0025           2
#
#      Density  (P/Km²)  Land Area (Km²)  Migrants (net) Fert. Rate Med. Age  \
# 0                 153          9388211       -348399.0        1.7       38
# 1                 464          2973190       -532687.0        2.2       28
# ...

# %%
pop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 235 entries, 0 to 234
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Countries         235 non-null    object
#  1   Population        235 non-null    int64
#  2   Yearly Change     235 non-null    float64
#  3   Net Change        235 non-null    int64
#  4   Density  (P/Km²)  235 non-null    int64
#  5   Land Area (Km²)   235 non-null    int64
#  6   Migrants (net)    201 non-null    float64
#  7   Fert. Rate        235 non-null    object
#  8   Med. Age          235 non-null    object
#  9   Urban Pop %       235 non-null    object
#  10  World Share       235 non-null    float64
#  11  Capital           235 non-null    object
#  12  Continent         235 non-null    object
#  13  Continent_pop     235 non-null    int64
# dtypes: float64(3), int64(5), object(6)
# memory usage: 25.8+ KB

# %%
pop["Population"]=pop["Population"].astype("int64")

# %%
pop["Population"]=pop["Population"].astype("int64")

# %%
pop["Continent"].value_counts()
# Out:
# Africa           52
# Asia             48
# Europe           45
# North America    34
# Oceania          22
# not defined      20
# South America    14
# Name: Continent, dtype: int64

# %%
Top_5_Pop=pop.head(5)
Top_5_Pop
# Out:
#        Countries  Population  Yearly Change  Net Change  Density  (P/Km²)  \
# 0          China  1439323776         0.0039     5540090               153
# 1          India  1380004385         0.0099    13586631               464
# 2  United States   331002651         0.0059     1937734                36
# 3      Indonesia   273523615         0.0107     2898047               151
# 4       Pakistan   220892340         0.0200     4327022               287
#
#    Land Area (Km²)  Migrants (net) Fert. Rate Med. Age Urban Pop %  \
# 0          9388211       -348399.0        1.7       38        0.61
# 1          2973190       -532687.0        2.2       28        0.35
# 2          9147420        954806.0        1.8       38        0.83
# 3          1811570        -98955.0        2.3       30        0.56
# 4           770880       -233379.0        3.6       23        0.35
#
#    World Share           Capital      Continent  Continent_pop
# ...

# %%
Top_5_Pop.plot(x="Countries",y="Population",kind="bar",xlabel="Countries",ylabel="Population(billions)",color="r")
               
plt.title("Top_5_Population",fontsize=15)

plt.show()

# %%
Top_Density=(pop.sort_values(by="Density  (P/Km²)",ascending=False,ignore_index=True)).head(5)
type(Top_Density)
# Out:
# pandas.core.frame.DataFrame

# %%
Top_Density.plot(x="Countries",y="Density  (P/Km²)",color="r",xlabel="Countries",ylabel="Persons Per km²"
                 ,kind="bar")
plt.title("Top Countreis of Density",fontsize=15)
# Out:
# Text(0.5, 1.0, 'Top Countreis of Density')

# %%
pop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 235 entries, 0 to 234
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Countries         235 non-null    object
#  1   Population        235 non-null    int64
#  2   Yearly Change     235 non-null    float64
#  3   Net Change        235 non-null    int64
#  4   Density  (P/Km²)  235 non-null    int64
#  5   Land Area (Km²)   235 non-null    int64
#  6   Migrants (net)    201 non-null    float64
#  7   Fert. Rate        235 non-null    object
#  8   Med. Age          235 non-null    object
#  9   Urban Pop %       235 non-null    object
#  10  World Share       235 non-null    float64
#  11  Capital           235 non-null    object
#  12  Continent         235 non-null    object
#  13  Continent_pop     235 non-null    int64
# dtypes: float64(3), int64(5), object(6)
# memory usage: 25.8+ KB

# %%
Top_Yearly_change=pop.sort_values(by="Yearly Change",ascending=False,ignore_index=False).head(5)
Top_Yearly_change
# Out:
#              Countries  Population  Yearly Change  Net Change  \
# 55               Niger    24206644         0.0384      895929
# 151            Bahrain     1701575         0.0368       60403
# 152  Equatorial Guinea     1402985         0.0347       46999
# 30              Uganda    45741007         0.0332     1471413
# 43              Angola    32866272         0.0327     1040977
#
#      Density  (P/Km²)  Land Area (Km²)  Migrants (net) Fert. Rate Med. Age  \
# 55                 19          1266700          4000.0          7       15
# 151              2239              760         47800.0          2       32
# 152                50            28050         16000.0        4.6       22
# 30                229           199810        168694.0          5       17
# 43                 26          1246700          6413.0        5.6       17
#
#     Urban Pop %  World Share  Capital Continent  Continent_pop
# 55         0.17       0.0031   Niamey    Africa     1307025251
# ...

# %%
plt.bar(Top_Yearly_change["Countries"],Top_Yearly_change["Yearly Change"],color="r")
plt.xlabel("Countries",fontsize=10)
plt.ylabel("Yearly Change")
plt.title("Top Yearly Change Countries",fontsize=15)
# Out:
# Text(0.5, 1.0, 'Top Yearly Change Countries')

# %%
Top_Net_change=pop.sort_values(by="Net Change",ascending=False,ignore_index=False).head(5)
Top_Net_change
# Out:
#    Countries  Population  Yearly Change  Net Change  Density  (P/Km²)  \
# 1      India  1380004385         0.0099    13586631               464
# 0      China  1439323776         0.0039     5540090               153
# 6    Nigeria   206139589         0.0258     5175990               226
# 4   Pakistan   220892340         0.0200     4327022               287
# 3  Indonesia   273523615         0.0107     2898047               151
#
#    Land Area (Km²)  Migrants (net) Fert. Rate Med. Age Urban Pop %  \
# 1          2973190       -532687.0        2.2       28        0.35
# 0          9388211       -348399.0        1.7       38        0.61
# 6           910770        -60000.0        5.4       18        0.52
# 4           770880       -233379.0        3.6       23        0.35
# 3          1811570        -98955.0        2.3       30        0.56
#
#    World Share    Capital Continent  Continent_pop
# 1       0.1770  New Delhi      Asia     4634096667
# ...

# %%
renam={"Country (or dependency)":"Countries"}
pop.rename(columns=renam)
# Out:
#             Countries  Population  Yearly Change  Net Change  \
# 0               China  1439323776         0.0039     5540090
# 1               India  1380004385         0.0099    13586631
# 2       United States   331002651         0.0059     1937734
# 3           Indonesia   273523615         0.0107     2898047
# 4            Pakistan   220892340         0.0200     4327022
# ..                ...         ...            ...         ...
# 230        Montserrat        4992         0.0006           3
# 231  Falkland Islands        3480         0.0305         103
# 232              Niue        1626         0.0068          11
# 233           Tokelau        1357         0.0127          17
# 234          Holy See         801         0.0025           2
#
#      Density  (P/Km²)  Land Area (Km²)  Migrants (net) Fert. Rate Med. Age  \
# 0                 153          9388211       -348399.0        1.7       38
# 1                 464          2973190       -532687.0        2.2       28
# ...

# %%
Top_Net_change.plot(x="Countries",y="Net Change",kind="bar",xlabel="Countries",ylabel="Net_change(millions)*10)",color="r")
plt.title("Top Countries of Net change ",fontsize=15)
# Out:
# Text(0.5, 1.0, 'Top Countries of Net change ')

# %%
Low_5_pop=pop.sort_values(by="Population",ascending=True,ignore_index=False).head(5)
Low_5_pop
# Out:
#             Countries  Population  Yearly Change  Net Change  \
# 234          Holy See         801         0.0025           2
# 233           Tokelau        1357         0.0127          17
# 232              Niue        1626         0.0068          11
# 231  Falkland Islands        3480         0.0305         103
# 230        Montserrat        4992         0.0006           3
#
#      Density  (P/Km²)  Land Area (Km²)  Migrants (net) Fert. Rate Med. Age  \
# 234              2003                0             NaN       N.A.     N.A.
# 233               136               10             NaN       N.A.     N.A.
# 232                 6              260             NaN       N.A.     N.A.
# 231                 0            12170             NaN       N.A.     N.A.
# 230                50              100             NaN       N.A.     N.A.
#
#     Urban Pop %  World Share      Capital      Continent  Continent_pop
# 234        N.A.          0.0  not defined    not defined       50770783
# ...

# %%
Low_5_pop.plot(x="Countries",y="Population",kind="bar",color="g",xlabel="Countries",ylabel="Population")
plt.title("Low_5_Population",fontsize=15)
plt.show()

# %%
Low_5_Density=(pop.sort_values(by="Density  (P/Km²)",ascending=True,ignore_index=False)).head(5)
Low_5_Density
# Out:
#             Countries  Population  Yearly Change  Net Change  \
# 208         Greenland       56770         0.0017          98
# 231  Falkland Islands        3480         0.0305         103
# 169    Western Sahara      597339         0.0255       14876
# 135          Mongolia     3278290         0.0165       53123
# 54          Australia    25499884         0.0118      296686
#
#      Density  (P/Km²)  Land Area (Km²)  Migrants (net) Fert. Rate Med. Age  \
# 208                 0           410450             NaN       N.A.     N.A.
# 231                 0            12170             NaN       N.A.     N.A.
# 169                 2           266000          5582.0        2.4       28
# 135                 2          1553560          -852.0        2.9       28
# 54                  3          7682300        158246.0        1.8       38
#
#     Urban Pop %  World Share      Capital      Continent  Continent_pop
# 208        0.87       0.0000         Nuuk  North America      591568821
# ...

# %%
Low_5_Density.plot(x="Countries",y="Density  (P/Km²)",kind="bar",color="g",xlabel="Countries",ylabel="Persons per Km²")
plt.title("Low Countries Of Density ",fontsize=15)
plt.show()

# %%
Low_Yearly_change=pop.sort_values(by="Yearly Change",ascending=True,ignore_index=False).head(5)
Low_Yearly_change
# Out:
#            Countries  Population  Yearly Change  Net Change  Density  (P/Km²)  \
# 140      Puerto Rico     2860853        -0.0247      -72555               323
# 225  Wallis & Futuna       11239        -0.0169        -193                80
# 141        Lithuania     2722289        -0.0135      -37338                43
# 150           Latvia     1886198        -0.0108      -20545                30
# 106         Bulgaria     6948445        -0.0074      -51674                64
#
#      Land Area (Km²)  Migrants (net) Fert. Rate Med. Age Urban Pop %  \
# 140             8870        -97986.0        1.2       44        N.A.
# 225              140             NaN       N.A.     N.A.           0
# 141            62674        -32780.0        1.7       45        0.71
# 150            62200        -14837.0        1.7       44        0.69
# 106           108560         -4800.0        1.6       45        0.76
#
#      World Share      Capital      Continent  Continent_pop
# ...

# %%
Low_Yearly_change.plot(x="Countries",y="Yearly Change",kind="barh",color="g",xlabel="Countries",ylabel="Population")
plt.title("Low_Yearly_change Countries",fontsize=15)
plt.show()

# %%
Low_Net_change=pop.sort_values(by="Net Change",ascending=True,ignore_index=False).head(5)
Low_Net_change
# Out:
#     Countries  Population  Yearly Change  Net Change  Density  (P/Km²)  \
# 10      Japan   126476461        -0.0030     -383840               347
# 34    Ukraine    43733762        -0.0059     -259876                75
# 60    Romania    19237691        -0.0066     -126866                84
# 22      Italy    60461826        -0.0015      -88249               206
# 49  Venezuela    28435940        -0.0028      -79889                32
#
#     Land Area (Km²)  Migrants (net) Fert. Rate Med. Age Urban Pop %  \
# 10           364555         71560.0        1.4       48        0.92
# 34           579320         10000.0        1.4       41        0.69
# 60           230170        -73999.0        1.6       43        0.55
# 22           294140        148943.0        1.3       47        0.69
# 49           882050       -653249.0        2.3       30        N.A.
#
#     World Share    Capital      Continent  Continent_pop
# 10       0.0162      Tokyo           Asia     4634096667
# ...

# %%
Low_Net_change.plot(x="Countries",y="Net Change",kind="barh",color="g",xlabel="Countries",ylabel="Change Value",)
plt.xticks(rotation=90)
plt.title("Low Population Change ",fontsize=15)
plt.show()

# %% [markdown]
# #                                     High Population

# %%
fig,axis=plt.subplots(nrows=2,ncols=2,figsize=(15,10))
fig.suptitle("High_Population",fontsize=20)
fig.patch.set_facecolor("#e6e6e6")
axis[0][0].bar(Top_5_Pop["Countries"],Top_5_Pop["Population"],color="r")
axis[0][0].set_title("Top_5_Population",fontsize=15)
axis[0][1].bar(Top_Density["Countries"],Top_Density["Population"],color="r")
axis[0][1].set_title("Top_Density",fontsize=15)
axis[1][0].bar(Top_Yearly_change["Countries"],Top_Yearly_change["Population"],color="r")
axis[1][0].set_title("Top_Yearly_change",fontsize=15)
axis[1][0].bar(Top_Yearly_change["Countries"],Top_Yearly_change["Population"],color="r")
axis[1][1].set_title("Top_Net_change",fontsize=15)
axis[1][1].bar(Top_Net_change["Countries"],Top_Net_change["Population"],color="r")
plt.show()

# %% [markdown]
# # Low Population

# %%
fig,axis=plt.subplots(nrows=2,ncols=2,figsize=(20,10))
plt.xticks(rotation=90)
fig.suptitle("Low_Population",fontsize=25)
fig.patch.set_facecolor("#e6e6e6")
axis[0][0].bar(Low_5_pop["Countries"],Low_5_pop["Population"],color="r")
axis[0][0].set_title("Low_5_pop",fontsize=15)
axis[0][1].bar(Low_5_Density["Countries"],Low_5_Density["Population"],color="r")
axis[0][1].set_title("Low_5_Density",fontsize=15)
plt.subplot(2,2,3)
plt.xticks(rotation=90)
axis[1][0].bar(Low_Yearly_change["Countries"],Low_Yearly_change["Population"],color="r")
axis[1][0].set_title("Low_Net_change",fontsize=15)
axis[1][0].bar(Low_Net_change["Countries"],Low_Net_change["Population"],color="r")
axis[1][1].set_title("Low_Yearly_change",fontsize=15)
axis[1][1].bar(Low_Yearly_change["Countries"],Low_Yearly_change["Population"],color="r")

plt.show()
